# %% [markdown]
# # **pandas-profiling Kütüphanesi**

# %% [markdown]
# # KAYNAK GITHUB SAYFASI
# https://github.com/pandas-profiling/pandas-profiling
#
# ## **Kurulum**
# ### pip install pandas-profiling
# ya da
# ### conda install -c anaconda pandas-profiling
# ## pandas-profiling ile her sütun için, aşağıdaki istatistikler - sütun türüyle ilgiliyse - etkileşimli bir HTML raporunda sunulur:
# * **Temel** : Tür, benzersiz değerler, eksik değerler
# * **Kuantil istatistikler** :Minimum değer, Q1, ortanca, Q3, maksimum, aralık, çeyrekler arası aralık gibi
# * **İstatistiki Değerler** :Ortalama, mod, standart sapma, toplam, medyan mutlak sapma, varyasyon katsayısı,
# * **En sık görülen değerler**
# * **Histogram**
# * **Korelasyonlar** : Korelasyon değerleri, Spearman ve Pearson matrisleri

# %% [markdown]
# ## GEREKLİ KÜTÜPHANELER

# %%
import pandas as pd
import pandas_profiling

# %% [markdown]
# # ÖRNEK BİR VERİ ALALIM

# %%
data=pd.read_csv('data.csv')

# %% [markdown]
# # DETAYLI RAPORU OLUŞTURALIM

# %%
pandas_profiling.ProfileReport(data)
# Out:
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
# ...

# %% [markdown]
# # FAYDALI OLMASI DİLEĞİYLE
